# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
opt=pd.read_hdf("optimisation.hd5")
print opt.columns
# Out:
# Index([u'clip_weight', u'learning_rate', u'max_depth', u'n_estimators',
#        u'reg_lambda', u'subsample', u'accu_mean', u'accu_stdev', u'cross_mean',
#        u'cross_stdev'],
#       dtype='object')

# %%
opt.plot.scatter(x='learning_rate',y='accu_mean',yerr='accu_stdev')
plt.show()

# %%
opt.plot.scatter(x='max_depth',y='accu_mean',yerr='accu_stdev')
plt.show()

# %%
opt.plot.scatter(x='n_estimators',y='accu_mean',yerr='accu_stdev')
plt.show()

# %%
opt.plot.scatter(x='reg_lambda',y='accu_mean',yerr='accu_stdev')
plt.show()

# %%
opt.plot.scatter(x='subsample',y='accu_mean',yerr='accu_stdev')
plt.show()

# %%
opt.plot.scatter(x='learning_rate',y='cross_mean',yerr='cross_stdev')
plt.show()

# %%
opt.plot.scatter(x='max_depth',y='cross_mean',yerr='cross_stdev')
plt.show()

# %%
opt.plot.scatter(x='n_estimators',y='cross_mean',yerr='cross_stdev')
plt.show()

# %%
opt.plot.scatter(x='reg_lambda',y='cross_mean',yerr='cross_stdev')
plt.show()

# %%
opt.plot.scatter(x='subsample',y='cross_mean',yerr='cross_stdev')
plt.show()
